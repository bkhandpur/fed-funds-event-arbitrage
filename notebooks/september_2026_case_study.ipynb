# %% [markdown]
# # September 16, 2026 case study
#
# Historical/user-supplied fixture. The observations are not necessarily synchronized or executable. The 25 bp equivalent probability is not unconditionally the probability of exactly a 25 bp move.

# %%
from fomc_basis.services.analysis import analyze_september_2026_fixture

result = analyze_september_2026_fixture()
result["futures_implied"], result["25_BP_EQUIVALENT_PROBABILITY_INTERVAL"]

# %%
result["tail_adjustment"], result["fees"], result["classification"], result["conclusion"]
